# %% [markdown]
# # Tratamento dos dados
#
# Aqui pode-se encontrar o tratamento dos banco de dados. Nessa etapa se retira os dados incoerentes, trata-se dados ausentes, classifca-se as colunas em tipos especificos de dados que podem favorecer no futuro e outros tipos de aperfeiçoamento que possa haver nas planilhas de dados. Vale resoltar que abaixo estão listados as colunas e o que cada uma delas se refere, além de dados que são mais relevantes e relações que possuem potencial de fornecer insights futuramente.

# %% [markdown]
# ### Descrição de cada coluna
# - product_category_name = categoria do produto
# - product_category_name_english = categoria do produto em inglês
# - customer_id = id do consumidor
# - customer_unique_id = id unico do consumidor
# - customer_zip_code_prefix = codigo zip do consumidor
# - customer_city = cidade do consumidor
# - customer_state = estado do consumidor
# - order_id = código id do pedido
# - order_item_id = código id do item
# - product_id = código id do produto
# - seller_id = código id do vendedor
# - shipping_limit_date = data limite de envio
# - price = preço
# - freight_value = preço do frete
# - payment_sequential = quantidade de pagamentos
# - payment_type = tipo de pagamento
# - payment_installments = quantidade de parcelas do pagamento
# - payment_value = valor do pagamento
# - review_id = código id da review
# - review_score = avaliação da review
# - review_comment_title = titulo da review
# - review_comment_message = comentario da review
# - review_creation_date = criação da review
# - review_answer_timestamp = resposta da review
# - order_status = estado da ordem
# - order_purchase_timestamp = data e hora em que o pedido foi feito
# - order_approved_at = data e hora em que o pedido foi aprovado
# - order_delivered_carrier_date = data em que o pedido foi entregue à transportadora
# - order_delivered_customer_date = data em que o pedido foi entregue ao cliente
# - delivery_time = tempo total de entrega, calculado desde o momento em que o pedido foi feito até o momento em que foi entregue ao cliente
# - delivery_time_model = tempo total estimado pela empresa para fazer a entrega
# - product_name_lenght = comprimento do nome do produto
# - product_description_lenght = comprimento da descrição do produto
# - product_photos_qty = quantidade de imagens do produto
# - product_weight_g = peso do produto
# - product_length_cm = comprimento do produto
# - product_height_cm = altura do produto
# - product_width_cm = largura do produto
# - seller_zip_code_prefix = código zip do vendedor
# - seller_city = cidade do vendedor
# - seller_state = estado do vendedor
#
# OBS: Existiam no começo 7 colunas reptidas.

# %% [markdown]
# ### Anotações diogo
# - Criar coluna distância
# - Criar colunas de dados das cidades
# - Colcar cidade e estado onde ta vazio*
# - Colunas categoricas: Plotar grafico de barras, ...
#     binario
# - Relações relevantes: Médias por cidade,
# - Tipo de grafico que mais gostam dispersão, colunas, pizzar e
# - Fluxo e grafos nadave
#
# ### Dados relevantes
# - Preço do frete
# - Tempo estimado
# - Tempo real
# - Distancia*
# - Cidade do comprador e cidade do vendedor
# - População/tamanho da cidade*
# - Tipo de pagamento
# - Categoria do produto
# - Tamanho
# - Peso
# - Avaliação
#
# ### Relações que possam fazer sentido
# - Tempo estima x tempo real -
# - Distancia x tempo real -
# - Tipo de pagamento x tempo real -
# - Cidade do comprador x tempo real -
# - Cidade do vendedor x tempo real -
# - Avaliação x tempo real -
# - Categoria do produto x tempo real -
# - Peso x tempo real -
#
# - Tamanho x frete -
# - Peso x frete -
# - Categoria do produto x frete -
# - Tipo de pagamento x frete -
# - Categoria do produto x tempo real -

# %%
# Realizando os imports
import pandas as pd
import numpy as np
import os
from concurrent.futures import ThreadPoolExecutor, as_completed

# %%
# Impostando a dataBase e imprimindo
df = pd.read_excel('./baseDeDados/dataBase.xlsx')
df
# Out:
#         product_category_name product_category_name_english  \
# 0       utilidades_domesticas                    housewares
# 1       utilidades_domesticas                    housewares
# 2       utilidades_domesticas                    housewares
# 3                    pet_shop                      pet_shop
# 4                   papelaria                    stationery
# ...                       ...                           ...
# 80278                   bebes                          baby
# 80279      eletrodomesticos_2             home_appliances_2
# 80280  informatica_acessorios         computers_accessories
# 80281  informatica_acessorios         computers_accessories
# 80282            beleza_saude                 health_beauty
#
#                             customer_id                customer_unique_id  \
# 0      9ef432eb6251297304e76186b10a928d  7c396fd4830fd04220f754e42b4e5bff
# 1      9ef432eb6251297304e76186b10a928d  7c396fd4830fd04220f754e42b4e5bff
# ...

# %%
# Impostando a dataBase e imprimindo
dfCEP = pd.read_excel('./baseDeDados/listaCEP.xlsx')
dfCEP
# Out:
#          Estado      Localidade           Faixa de CEP  CEP Inicial  \
# 0          acre      acrelândia  69945-000 a 69949-999        69945
# 1          acre    assis brasil  69935-000 a 69939-999        69935
# 2          acre       brasiléia  69932-000 a 69933-999        69932
# 3          acre          bujari  69926-000 a 69926-999        69926
# 4          acre        capixaba  69931-000 a 69931-999        69931
# ...         ...             ...                    ...          ...
# 6010  tocantins  tocantinópolis  77900-000 a 77902-999        77900
# 6011  tocantins        tupirama  77704-000 a 77707-999        77704
# 6012  tocantins      tupiratins  77743-000 a 77744-999        77743
# 6013  tocantins    wanderlândia  77860-000 a 77869-999        77860
# 6014  tocantins         xambioá  77880-000 a 77884-999        77880
#
#       CEP Final                        Situação       Tipo de Faixa
# 0         69950  Não codificada por logradouros  Total do município
# ...

# %%
# Deletando colunas e linhas duplicadas
df = df.T.drop_duplicates().T

# %%
# Transformando todos os estado para o nome completo

for i in range(0, len(df)):
    if str(df['customer_state'][i]) == "AC":
        df['customer_state'][i] = "acre"
    elif str(df['customer_state'][i]) == "AL":
        df['customer_state'][i] = "alagoas"
    elif str(df['customer_state'][i]) == "AP":
        df['customer_state'][i] = "amapa"
    elif str(df['customer_state'][i]) == "AM":
        df['customer_state'][i] = "amazonas"
    elif str(df['customer_state'][i]) == "BA":
        df['customer_state'][i] = "bahia"
    elif str(df['customer_state'][i]) == "CE":
        df['customer_state'][i] = "ceara"
    elif str(df['customer_state'][i]) == "ES":
        df['customer_state'][i] = "espirito santo"
    elif str(df['customer_state'][i]) == "GO":
        df['customer_state'][i] = "goias"
    elif str(df['customer_state'][i]) == "MA":
        df['customer_state'][i] = "maranhao"
    elif str(df['customer_state'][i]) == "MT":
        df['customer_state'][i] = "mato grosso"
    elif str(df['customer_state'][i]) == "MS":
        df['customer_state'][i] = "mato grosso do sul"
    elif str(df['customer_state'][i]) == "MG":
        df['customer_state'][i] = "minas gerais"
    elif str(df['customer_state'][i]) == "PA":
        df['customer_state'][i] = "para"
    elif str(df['customer_state'][i]) == "PB":
        df['customer_state'][i] = "paraiba"
    elif str(df['customer_state'][i]) == "PR":
        df['customer_state'][i] = "parana"
    elif str(df['customer_state'][i]) == "PE":
        df['customer_state'][i] = "pernambuco"
    elif str(df['customer_state'][i]) == "PI":
        df['customer_state'][i] = "piaui"
    elif str(df['customer_state'][i]) == "RJ":
        df['customer_state'][i] = "rio de janeiro"
    elif str(df['customer_state'][i]) == "RN":
        df['customer_state'][i] = "rio grande do norte"
    elif str(df['customer_state'][i]) == "RS":
        df['customer_state'][i] = "rio grande do sul"
    elif str(df['customer_state'][i]) == "RO":
        df['customer_state'][i] = "rondonia"
    elif str(df['customer_state'][i]) == "RR":
        df['customer_state'][i] = "roraima"
    elif str(df['customer_state'][i]) == "SC":
        df['customer_state'][i] = "santa catarina"
    elif str(df['customer_state'][i]) == "SP":
        df['customer_state'][i] = "sao paulo"
    elif str(df['customer_state'][i]) == "SE":
        df['customer_state'][i] = "sergipe"
    elif str(df['customer_state'][i]) == "TO":
        df['customer_state'][i] = "tocantins"
    elif str(df['customer_state'][i]) == "DF":
        df['customer_state'][i] = "distrito federal"
# Out:
# C:\Users\leopa\AppData\Local\Temp\ipykernel_9004\113707006.py:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['customer_state'][i] = "rio grande do norte"
# ...

# %%
# Completando a cidade e estado do comprador com base no zip code
for i in range(0, len(df)):
    if str(df['customer_city'][i]) == 'nan' or str(df['customer_state'][i]) == 'nan':
        for j in range(0, len(dfCEP)):
            if (df['customer_zip_code_prefix'][i] >= dfCEP['CEP Inicial'][j]) and (df['customer_zip_code_prefix'][i] <= dfCEP['CEP Final'][j]):
                df['customer_city'][i] = dfCEP['Localidade'][j]
                df['customer_state'][i] = dfCEP['Estado'][j]
                break
# Out:
# C:\Users\leopa\AppData\Local\Temp\ipykernel_9004\1611475942.py:6: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['customer_city'][i] = dfCEP['Localidade'][j]
# ...

# %%
# Colocando os estados e as cidades em letra minuscula
for i in range(0, len(df)):
    df['customer_city'][i] = str(df['customer_city'][i]).lower()
    df['customer_state'][i] = str(df['customer_state'][i]).lower()
# Out:
# /tmp/ipykernel_48787/2700508489.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['customer_city'][i] = str(df['customer_city'][i]).lower()
# ...

# %%
# Transformação de valores

# Transformando numeros
df['customer_zip_code_prefix'] = pd.to_numeric(df['customer_zip_code_prefix'], errors = 'coerce')
df['order_item_id'] = pd.to_numeric(df['order_item_id'], errors = 'coerce')
df['price'] = pd.to_numeric(df['price'], errors = 'coerce')
df['freight_value'] = pd.to_numeric(df['freight_value'], errors = 'coerce')
df['payment_sequential'] = pd.to_numeric(df['payment_sequential'], errors = 'coerce')
df['payment_installments'] = pd.to_numeric(df['payment_installments'], errors = 'coerce')
df['payment_value'] = pd.to_numeric(df['payment_value'], errors = 'coerce')
df['review_score'] = pd.to_numeric(df['review_score'], errors = 'coerce')
df['delivery_time'] = pd.to_numeric(df['delivery_time'], errors = 'coerce')
df['delivery_time_model'] = pd.to_numeric(df['delivery_time_model'], errors = 'coerce')
df['product_name_lenght'] = pd.to_numeric(df['product_name_lenght'], errors = 'coerce')
df['product_description_lenght'] = pd.to_numeric(df['product_description_lenght'], errors = 'coerce')
df['product_photos_qty'] = pd.to_numeric(df['product_photos_qty'], errors = 'coerce')
df['product_weight_g'] = pd.to_numeric(df['product_weight_g'], errors = 'coerce')
df['product_length_cm'] = pd.to_numeric(df['product_length_cm'], errors = 'coerce')
df['product_height_cm'] = pd.to_numeric(df['product_height_cm'], errors = 'coerce')
df['product_width_cm'] = pd.to_numeric(df['product_width_cm'], errors = 'coerce')
df['seller_zip_code_prefix'] = pd.to_numeric(df['seller_zip_code_prefix'], errors = 'coerce')

# Transformando as colunas de data para o tipo datetime
df['shipping_limit_date'] = pd.to_datetime(df['shipping_limit_date'], errors='coerce')
df['review_creation_date'] = pd.to_datetime(df['review_creation_date'], errors='coerce')
df['review_answer_timestamp'] = pd.to_datetime(df['review_answer_timestamp'], errors='coerce')
df['order_purchase_timestamp'] = pd.to_datetime(df['order_purchase_timestamp'], errors='coerce')
df['order_approved_at'] = pd.to_datetime(df['order_approved_at'], errors='coerce')
df['order_delivered_carrier_date'] = pd.to_datetime(df['order_delivered_carrier_date'], errors='coerce')
df['order_delivered_customer_date'] = pd.to_datetime(df['order_delivered_customer_date'], errors='coerce')

# %%
# Tratando valores nulos
for coluna in df.columns:
    if (str(df[coluna].dtypes)) == 'float64' or (str(df[coluna].dtypes)) == 'int64':
        df[coluna].fillna(df[coluna].mean(), inplace = True)
    elif df[coluna].dtype == 'datetime64[ns]':
        df[coluna].fillna(pd.NaT, inplace=True)
    else:
        df[coluna].fillna("Ausente", inplace = True)
# Out:
# C:\Users\leopa\AppData\Local\Temp\ipykernel_9004\1808992906.py:8: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[coluna].fillna("Ausente", inplace = True)
# C:\Users\leopa\AppData\Local\Temp\ipykernel_9004\1808992906.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
# Transformando em categoricas
df['product_category_name'] = df['product_category_name'].astype('category')
df['product_category_name_english'] = df['product_category_name_english'].astype('category')
df['payment_type'] = df['payment_type'].astype('category')
df['product_category_name'] = df['product_category_name'].astype('category')
df['customer_city'] = df['customer_city'].astype('category')
df['customer_state'] = df['customer_state'].astype('category')
df['seller_city'] = df['seller_city'].astype('category')
df['seller_state'] = df['seller_state'].astype('category')

# %%
# Identificador de outliers
def drop_outliers(base, variavel):
    outliers = []
    # Calcula Q1 (25º percentil) para a variável dada
    Q1 = np.percentile(base[variavel], 25)
    
    # Calcula Q3 (75º percentil) para a variável dada
    Q3 = np.percentile(base[variavel], 75)
    
    # Usa IQR (interquartile range) para calcular um passo de outlier
    IQR = Q3-Q1
    passo = 1.5 * IQR
    
    feature_outliers = base[~((base[variavel] >= Q1 - passo) & (base[variavel] <= Q3 + passo))]
    outliers.extend(list(feature_outliers.index.values))
    
    return outliers

# %%
# Retirando todos os outliers dos valores numericos

for coluna in df.columns:
    if (str(df[coluna].dtypes)) == 'float64' or (str(df[coluna].dtypes)) == 'int64':
        outliers = drop_outliers(df, str(coluna))
        dfSemOutliers = df.drop(df.index[outliers]).reset_index(drop = True)

df = dfSemOutliers

# %%
# Convertendo os valores negativos da review para positvos
df['review_score'] = df['review_score'].abs()

# %%
# Deletando as linhas nas quais o status do pedido é classificado como cancelado pois existem apenas 6 linhas assim
df = df[df['order_status'] != 'canceled']

# %%
# Calculando o tempo levado para o pedido ser aceito, o tempo levado para o pedido chegar na transportadora após aceito 
# e o tempo levado pro pedido sair da transportadora e chegar no cliente

# Criando funções para calcular os tempos
def calcularTempoEntregaTransportadora(row):
    diferencaCompleta = row['order_delivered_carrier_date'] - row['order_approved_at']
    diferencaEmDias = diferencaCompleta.total_seconds() / (24 * 3600)
    return diferencaEmDias

def calcularTempoAceitarPedido(row):
    diferencaCompleta = row['order_approved_at'] - row['order_purchase_timestamp']
    diferencaEmDias = diferencaCompleta.total_seconds() / (24 * 3600)
    return diferencaEmDias

def calcularTempoEntregaCliente(row):
    diferencaCompleta = row['order_delivered_customer_date'] - row['order_delivered_carrier_date']
    diferencaEmDias = diferencaCompleta.total_seconds() / (24 * 3600)
    return diferencaEmDias

# Fazendo uma cópia do DataFrame original para evitar modificações na visualização
df = df.copy()  

# Aplicando as funções a cada linha do DataFrame usando loc
df.loc[:, 'tempo_entrega_transportadora'] = df.apply(calcularTempoEntregaTransportadora, axis=1)
df.loc[:, 'tempo_aceitar_pedido'] = df.apply(calcularTempoAceitarPedido, axis=1)
df.loc[:, 'tempo_entrega_cliente'] = df.apply(calcularTempoEntregaCliente, axis=1)

# %%
pd.set_option('display.max_columns', None)

df[df['tempo_entrega_cliente']<0]
# Out:
#                product_category_name product_category_name_english  \
# 4330                moveis_decoracao               furniture_decor
# 4331               moveis_escritorio              office_furniture
# 4332                moveis_decoracao               furniture_decor
# 6492                moveis_decoracao               furniture_decor
# 6493                moveis_decoracao               furniture_decor
# 9143                moveis_decoracao               furniture_decor
# 9826                     eletronicos                   electronics
# 9827                     eletronicos                   electronics
# 9828                     eletronicos                   electronics
# 9829                     eletronicos                   electronics
# 9830                 cama_mesa_banho                bed_bath_table
# 9831                 cama_mesa_banho                bed_bath_table
# 9832                 cama_mesa_banho                bed_bath_table
# ...

# %%
df[df['tempo_entrega_transportadora']<0]
# Out:
#              product_category_name product_category_name_english  \
# 41                malas_acessorios           luggage_accessories
# 42          informatica_acessorios         computers_accessories
# 1268        informatica_acessorios         computers_accessories
# 1269        informatica_acessorios         computers_accessories
# 1312                 esporte_lazer                sports_leisure
# ...                            ...                           ...
# 67405  fashion_bolsas_e_acessorios      fashion_bags_accessories
# 67531           relogios_presentes                 watches_gifts
# 67532           relogios_presentes                 watches_gifts
# 67702                    telefonia                     telephony
# 67785              cama_mesa_banho                bed_bath_table
#
#                             customer_id                customer_unique_id  \
# 41     81e08b08e5ed4472008030d70327c71f  0e764fc1a13e47e900c3d59a989753e8
# ...

# %%
# Exportando tudo para um excel
#df.to_excel('./baseDeDados/dataBaseTratada.xlsx', sheet_name='dados', index=False)
