# %% [markdown]
# ### Análise dos dados

# %%
# Realizando os imports
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px

# %%
# Impostando a dataBase e imprimindo
df = pd.read_csv('./baseDeDados/dataBase.csv', low_memory=False)
df
# Out:
#         product_category_name product_category_name_english  \
# 0       utilidades_domesticas                    housewares
# 1       utilidades_domesticas                    housewares
# 2       utilidades_domesticas                    housewares
# 3                    pet_shop                      pet_shop
# 4                   papelaria                    stationery
# ...                       ...                           ...
# 80278                   bebes                          baby
# 80279      eletrodomesticos_2             home_appliances_2
# 80280  informatica_acessorios         computers_accessories
# 80281  informatica_acessorios         computers_accessories
# 80282            beleza_saude                 health_beauty
#
#                             customer_id                customer_unique_id  \
# 0      9ef432eb6251297304e76186b10a928d  7c396fd4830fd04220f754e42b4e5bff
# 1      9ef432eb6251297304e76186b10a928d  7c396fd4830fd04220f754e42b4e5bff
# ...

# %%
sns.heatmap(df.corr(), #df_corr.corr() cria uma matriz de correlação, 
#que é transformada em heatmap
annot=True,                 #Legenda em cada célula
vmin=-1, vmax=1,            #máximo e mínimo de correlação
cmap='BrBG')                #paleta de cores do gráfico
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 sns.heatmap(df.corr(), #df_corr.corr() cria uma matriz de correlação,
#       2 #que é transformada em heatmap
#       3 annot=True,                 #Legenda em cada célula
#       4 vmin=-1, vmax=1,            #máximo e mínimo de correlação
#       5 cmap='BrBG')                #paleta de cores do gráfico
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/frame.py:11022, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11020 cols = data.columns
#   11021 idx = cols.copy()
# > 11022 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11024 if method == "pearson":
#   11025     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/frame.py:1981, in DataFrame.to_numpy(self, dtype, copy, na_value)
# ...
